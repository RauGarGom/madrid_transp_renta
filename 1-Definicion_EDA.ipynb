# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# # Título:
# ## Transporte y renta en la Comunidad de Madrid

# %% [markdown]
# ### TEMA

# %% [markdown]
# Este proyecto busca arrojar luz sobre los patrones de comportamiento en el transporte de los ciudadanos de la Comunidad de Madrid, estudiando posibles vínculos con su renta. Para ello, se utiliza la [Encuesta de Movilidad del Consorcio Regional](https://datos.comunidad.madrid/dataset/resultados-edm2018) de Transportes de Madrid (CRTM), realizada en el 2018.
#
# Para los cálculos de la renta, se utilizan diferentes tablas extraídas de la [Encuesta de Condiciones de Vida](https://ine.es/dyngs/INEbase/es/operacion.htm?c=Estadistica_C&cid=1254736176807&menu=ultiDatos&idp=1254735976608) del INE, para el año 2018

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# La hipótesis principal de este proyecto es que **existe una relación entre la renta y el uso del transporte en la Comunidad de Madrid**. En concreto, se buscará contrastar:
# + Si las rentas más altas eligen el coche como primera opción para desplazamientos laborales y por placer.
# + Las rentas bajas, para trabajar, utilizan más el transporte público que el coche.
# + Las mujeres utilizan más el transporte público para desplazamientos laborales, sin tener en cuenta la renta.
#     + Lo que, unido al segundo punto, explicaría que las mujeres no usan más el transporte público por deseo sino por necesidad.
# + Los hombres utilizan más el transporte públiico para desplazamientos por placer

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd
### Importar openpyxl
# guarda en variables los datasets y su fuente
df_transp = pd.DataFrame(pd.read_csv("./data/crtm_public_transp.csv"))
fuente_1 = "https://www.kaggle.com/datasets/dataguapa/madrid-public-transportation-data-2018"

df_hogares = pd.DataFrame(pd.read_csv("./data/ine_gasto_hogares.csv", sep=";"))
fuente_2 = "https://www.ine.es/jaxiT3/Tabla.htm?t=24900"

df_ingresos = pd.DataFrame(pd.read_csv("./data/ine_madrid_fuentes_ingreso.csv",sep=";"))
fuente_3 = "https://ine.es/jaxiT3/Tabla.htm?t=53687"

df_renta_es = pd.DataFrame(pd.read_csv("./data/ine_renta_edad_sexo.csv",encoding='latin1',sep=";"))
fuente_4 = "https://ine.es/jaxiT3/Tabla.htm?t=9942"

df_5 = pd.DataFrame(pd.read_excel("./data/ine_renta_educacion.xlsx", sheet_name="educación")) ### Terminar de apañar
fuente_5 = "https://ine.es/ss/Satellite?c=INESeccion_C&cid=1259944504067&p=1254735110672&pagename=ProductosYServicios%2FPYSLayout&param1=PYSDetalleFichaIndicador&param3=1259937499084"
df_5
# Out:
#    Renta media y mediana equivalente(1) (de las personas de 18 y más años). Base 2013 (euros corrientes)  \
# 0                               Por unidad de consumo
# 1                                                 NaN
# 2                                               Media
# 3                                               Total
# 4   Nivel 0-2: preescolar, primaria y secundaria d...
# 5   Nivel 3-4: secundaria de 2ª etapa y postsecund...
# 6   Nivel 5-8: primer y segundo ciclo de educación...
# 7                                             Mediana
# 8                                               Total
# 9   Nivel 0-2: preescolar, primaria y secundaria d...
# 10  Nivel 3-4: secundaria de 2ª etapa y postsecund...
# 11  Nivel 5-8: primer y segundo ciclo de educación...
# 12  (1) corresponde al concepto de renta disponibl...
# 13       Fuente: Encuesta de Condiciones de Vida. INE
# 14                                                NaN
# 15                                                NaN
# 16  Renta media y mediana equivalente (1) (de las ...
# 17                              Por unidad de consumo
# 18                                                NaN
# 19                                              Media
# 20  Nivel 0-2: preescolar, primaria y secundaria d...
# 21  Nivel 3-4: secundaria de 2ª etapa y postsecund...
# 22  Nivel 5-8: primer y segundo ciclo de educación...
# 23                                            Mediana
# 24  Nivel 0-2: preescolar, primaria y secundaria d...
# 25  Nivel 3-4: secundaria de 2ª etapa y postsecund...
# 26  Nivel 5-8: primer y segundo ciclo de educación...
# 27  Mean and median income by educational attainme...
# 28  (1) corresponde al concepto de renta disponibl...
# 29       Fuente: Encuesta de Condiciones de Vida. INE
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0         NaN        NaN        NaN        NaN        NaN        NaN
# 1        2008       2009       2010       2011       2012       2013
# 2         NaN        NaN        NaN        NaN        NaN        NaN
# 3       16587      17422      17327      16604      16428      16023
# 4       13410      14071      13918      13290      13231      12926
# 5       17342      17725      17627      16978      16446      16131
# 6       22946      24515      24325      23285      22836      21838
# 7
# 8       14374      15106      14984      14222      14171      13826
# 9       12146      12899      12648      11957      11850      11654
# 10      15633      16198      15886      15274      14764      14584
# 11      20694      22216      21931      21006      20783      19777
# 12        NaN        NaN        NaN        NaN        NaN        NaN
# 13        NaN        NaN        NaN        NaN        NaN        NaN
# 14        NaN        NaN        NaN        NaN        NaN        NaN
# 15        NaN        NaN        NaN        NaN        NaN        NaN
# 16        NaN        NaN        NaN        NaN        NaN        NaN
# 17        NaN        NaN        NaN        NaN        NaN        NaN
# 18       2004       2005       2006       2007       2008       2009
# 19        NaN        NaN        NaN        NaN        NaN        NaN
# 20       9762      10257      10677      11360      12077      12193
# 21      12556      12942      13600      14064      15193      15360
# 22      16268      17247      18359      18818      20044      20716
# 23        NaN        NaN        NaN        NaN        NaN        NaN
# 24       8960       9257       9817      10435      11200      11329
# 25      11487      11976      12579      13154      14090      14250
# 26      14802      15689      16602      16950      18520      19204
# 27        NaN        NaN        NaN        NaN        NaN        NaN
# 28        NaN        NaN        NaN        NaN        NaN        NaN
# 29        NaN        NaN        NaN        NaN        NaN        NaN
#
#    Unnamed: 7 Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 0         NaN        NaN         NaN          NaN          NaN          NaN
# 1        2014       2015      2016.0       2017.0       2018.0       2019.0
# 2         NaN        NaN         NaN          NaN          NaN          NaN
# 3       15752      15716     16129.0      16677.0      17154.0      17570.0
# 4       12610      12435     12647.0      13052.0      13373.0      13890.0
# 5       15713      15555     16112.0      16399.0      16638.0      16999.0
# 6       21372      21579     22116.0      22783.0      23314.0      23436.0
# 7                                NaN          NaN          NaN          NaN
# 8       13590      13593     13941.0      14450.0      14979.0      15283.0
# 9       11314      11309     11567.0      11988.0      12176.0      12803.0
# 10      14135      14098     14455.0      14854.0      15117.0      15311.0
# 11      19503      19633     20006.0      20800.0      21285.0      21236.0
# 12        NaN        NaN         NaN          NaN          NaN          NaN
# 13        NaN        NaN         NaN          NaN          NaN          NaN
# 14        NaN        NaN         NaN          NaN          NaN          NaN
# 15        NaN        NaN         NaN          NaN          NaN          NaN
# 16        NaN        NaN         NaN          NaN          NaN          NaN
# 17        NaN        NaN         NaN          NaN          NaN          NaN
# 18       2010       2011      2012.0          NaN          NaN          NaN
# 19        NaN        NaN         NaN          NaN          NaN          NaN
# 20      12047      11737     11609.0          NaN          NaN          NaN
# 21      15080      14551     14336.0          NaN          NaN          NaN
# 22      20423      19751     19608.0          NaN          NaN          NaN
# 23        NaN        NaN         NaN          NaN          NaN          NaN
# 24      11195      10475     10440.0          NaN          NaN          NaN
# 25      14035      13544     12710.0          NaN          NaN          NaN
# 26      18879      18524     18063.0          NaN          NaN          NaN
# 27        NaN        NaN         NaN          NaN          NaN          NaN
# 28        NaN        NaN         NaN          NaN          NaN          NaN
# 29        NaN        NaN         NaN          NaN          NaN          NaN
#
#     Unnamed: 13  Unnamed: 14  Unnamed: 15
# 0           NaN          NaN          NaN
# 1        2020.0       2021.0       2022.0
# 2           NaN          NaN          NaN
# 3       18538.0      18480.0      19562.0
# 4       14682.0      14357.0      15289.0
# 5       17799.0      17798.0      18617.0
# 6       23924.0      23890.0      25089.0
# 7           NaN          NaN          NaN
# 8       16438.0      16275.0      17229.0
# 9       13600.0      13363.0      14133.0
# 10      16104.0      16067.0      16886.0
# 11      21847.0      21944.0      22717.0
# 12          NaN          NaN          NaN
# 13          NaN          NaN          NaN
# 14          NaN          NaN          NaN
# 15          NaN          NaN          NaN
# 16          NaN          NaN          NaN
# 17          NaN          NaN          NaN
# 18          NaN          NaN          NaN
# 19          NaN          NaN          NaN
# 20          NaN          NaN          NaN
# 21          NaN          NaN          NaN
# 22          NaN          NaN          NaN
# 23          NaN          NaN          NaN
# 24          NaN          NaN          NaN
# 25          NaN          NaN          NaN
# 26          NaN          NaN          NaN
# 27          NaN          NaN          NaN
# 28          NaN          NaN          NaN
# 29          NaN          NaN          NaN

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
# Primer dataset
# df_1.head()

# %%
# Siguiente dataset...
# df_2.head()
